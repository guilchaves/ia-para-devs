# %%
from langchain_community.document_loaders.generic import GenericLoader
from langchain_community.document_loaders.parsers import LanguageParser
from langchain_text_splitters import Language, RecursiveCharacterTextSplitter
from langchain_chroma import Chroma
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_classic.chains.question_answering import load_qa_chain
from langchain_core.prompts import ChatPromptTemplate
from langchain_classic.chains import create_retrieval_chain
from langchain_classic.chains.combine_documents import create_stuff_documents_chain

import os

from git import Repo

# %%
repo_path = "./test_repo"

# %%
repo = Repo.clone_from("https://github.com/langchain-ai/langchain", to_path=repo_path)

# %%
loader = GenericLoader.from_filesystem(
    repo_path + "/libs/core/langchain_core/",
    glob="**/*",
    suffixes = [".py"],
    exclude = ["**/non-utf-8-encoding.py"],
    parser = LanguageParser(language=Language.PYTHON, parser_threshold=500)
)

documents = loader.load()
len(documents)
# Out:
# 641

# %%
python_splitter = RecursiveCharacterTextSplitter.from_language(
    language=Language.PYTHON,
    chunk_size = 2000,
    chunk_overlap = 200
)

texts = python_splitter.split_documents(documents)
len(texts)
# Out:
# 1803

# %%
os.environ['OPENAI_API_KEY'] = ""

# %%
db = Chroma.from_documents(texts, OpenAIEmbeddings(disallowed_special=()))

retriever = db.as_retriever(
    search_type = "mmr",
    search_kwargs = {"k": 8}
)

# %%
llm = ChatOpenAI(model="gpt-3.5-turbo", max_tokens = 1000)

# %%
prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system", 
            "Você é um revisor de código experiente. Forneça informações detalhadas sobre a revisão do código e sugestões de melhorias baseado no contexto fornecido abaixo: \n\n {context}"
        ),
        ("user", "{input}")
    ]
)

document_chain = create_stuff_documents_chain(llm, prompt)

retrieval_chain = create_retrieval_chain(retriever, document_chain)

# %%
response = retrieval_chain.invoke({"input": "Revise e sugira melhorias para o código de RunnableBinding"})

# %%
print(response['answer'])
# Out:
# ### Revisão do código de `RunnableBinding`
#
# 1. **Documentação e Comentários:**
#    - A documentação fornecida para o método `bind` e `with_config` é muito clara e informativa, o que é ótimo.
#    - Sugiro adicionar docstrings para as classes `RunnableBinding` e `_RunnableCallableSync`, `_RunnableCallableAsync`, `_RunnableCallableIterator`, `_RunnableCallableAsyncIterator` para fornecer uma visão geral do propósito de cada uma.
#    - Certifique-se de adicionar comentários relevantes ao código para tornar mais fácil o entendimento para os futuros desenvolvedores.
#
# 2. **Boas Práticas:**
#    - No método `bind`, ao criar o novo `Runnable`, é boa prática usar a função `copy()` para criar uma cópia profunda do dicionário `self.kwargs` em vez de `self.kwargs, **kwargs` diretamente. Isso evita possíveis efeitos colaterais.
#    - No método `with_config`, um tipo mais específico pode ser usado em vez de fazer cast para `RunnableConfig`. Isso ajudará na verificação estática de tipos.
#    - Evite o uso de castings quando possível, pois pode levar a erros em tempo de execução. Certifique-se de que os tipos de dados são devidamente verificados antes de usar operadores de cast.
#
# 3. **Estilo de Codificação:**
#    - Mantenha a consistência na formatação e estilo do código. Certifique-se de que o código esteja de acordo com as diretrizes de estilo da linguagem Python, como PEP8.
#    - Certifique-se de seguir a convenção de nomeação adequada (snake_case) para funções e métodos.
#
# 4. **Clareza e Concisão:**
#    - O trecho de código `"from langchain_core.runnables import RunnableBinding"` pode não ser necessário, a menos que esteja faltando no código compartilhado.
#    - Evite comentários irrelevantes que apenas repetem o que já está evidente no código.
#    - Simplifique os comentários complexos, se possível, para tornar o código mais legível e claro.
#
# 5. **Eficiência e Desempenho:**
#    - No método `_executor()`, saiba que o uso de `ThreadPoolExecutor` possui um custo de sobrecarga de inicialização. Considere avaliar se a criação de um pool de threads é a melhor opção para o seu caso de uso, tendo em mente o overhead de criação de threads.
#
# ### Sugestões de Melhoria
#
# - Adicionar docstrings e comentários às classes e métodos para explicar seu propósito e funcionalidades.
# - Refatorar partes do código para seguir as boas práticas de codificação em Python.
# - Garantir consistência na formatação e estilo do código.
# - Remover trechos de código ou comentários desnecessários que não adicionam valor ao entendimento.
# - Avaliar a eficiência do uso de `ThreadPoolExecutor` em `_executor()` e considerar outras opções se necessário.
#
# Após essas melhorias, o código estará mais organizado, claro e alinhado com as melhores práticas de codificação em Python.
